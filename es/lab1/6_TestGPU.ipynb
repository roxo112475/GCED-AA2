# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eirasf/GCED-AA2/blob/main/es/lab1/6_TestGPU.ipynb)

# %%
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

if not torch.cuda.is_available():
    raise SystemError("GPU device not found")

device_name = torch.cuda.get_device_name(0)
print(f"Found GPU at: {device_name}")
# Out:
# Found GPU at: Tesla T4

# %%
import torch

a = torch.tensor([1, 2, 3], device=device)
b = torch.tensor([4, 5, 6], device=device)

# Hacemos la operación en el dispositivo que designamos en la celda anterior
c = a + b

# Forzamos hacer la operación en CPU
a = a.to("cpu")
b = b.to("cpu")
c = a + b
print(c)

# Esto funciona si tenemos GPU
a = a.to("cuda")
b = b.to("cuda")
c = a + b
print(c)
# Out:
# tensor([5, 7, 9])
# tensor([5, 7, 9], device='cuda:0')
